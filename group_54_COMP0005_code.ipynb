# %% [markdown]
# # COMP0005 - GROUP COURSEWORK
# # Experimental Evaluation of Search Data Structures and Algorithms

# %% [markdown]
# The cell below defines **AbstractSearchInterface**, an interface to support basic insert/search operations; you will need to implement this three times, to realise your three search data structures of choice among: (1) *2-3 Tree*, (2) *AVL Tree*, (3) *LLRB BST*; (4) *B-Tree*; and (5) *Scapegoat Tree*. <br><br>**Do NOT modify the next cell** - use the dedicated cells further below for your implementation instead. <br>

# %%
# DO NOT MODIFY THIS CELL
from abc import ABC, abstractmethod


class AbstractSearchInterface(ABC):
    """
    Abstract class to support search/insert operations (plus underlying data structure)

    """

    @abstractmethod
    def insertElement(self, element):
        """
        Insert an element in a search tree
            Parameters:
                    element: string to be inserted in the search tree (string)

            Returns:
                    "True" after successful insertion, "False" if element is already present (bool)
        """

        pass

    @abstractmethod
    def searchElement(self, element):
        """
        Search for an element in a search tree
            Parameters:
                    element: string to be searched in the search tree (string)

            Returns:
                    "True" if element is found, "False" otherwise (bool)
        """

        pass

# %% [markdown]
# ### Tree Nodes
# Use the cell below to define any auxiliary data structure and python function you may need. Leave the implementation of the main API to the next code cells instead.

# %%
# ADD AUXILIARY DATA STRUCTURE DEFINITIONS AND HELPER CODE HERE

class TwoThreeNode:
    """A node in a 2-3 tree. Stores keys and children as lists"""

    def __init__(self, keys=None, children=None):
        self.keys = keys or []
        self.children = children or []

    def is_leaf(self) -> bool:
        return len(self.children) == 0

class AVLNode:
    """Represents a node in an AVL tree."""

    def __init__(self, key: str):
        self.key: str = key
        self.height: int = 0
        self.left: AVLNode | None = None
        self.right: AVLNode | None = None

class LLRBNode:
    """A node in a LLRB tree. Has an extra property: colour"""

    def __init__(self, key):
        self.key: str = key
        self.left: LLRBNode | None = None
        self.right: LLRBNode | None = None
        self.colour: bool = True  # True for red; False for black

# %% [markdown]
# ### 2-3 Tree
# Use the cell below to implement the requested API by means of **2-3 Tree** (if among your chosen data structure).

# %%
"""
2-3 Tree Implementation:

A 2-3 tree is a balanced search tree in which:
- 2-nodes have one key and two children.
- 3-nodes have two keys and three children.
- All the leaf nodes lie at the same depth.

The tree is balanced by splitting overfull nodes (temporary nodes with 3 keys
and 4 children) into two 2-nodes, and passing the middle key up the tree.

The tree depth can only be increased by a split operation at the root node: this
is how the tree maintains balance. Splitting is a constant time operation and
only acts locally in the structure.

Deletion works using merge and redistribute tree operations.

Searching a 2-3 tree of N nodes is an O(logN) operation; inserting a node into
a 2-3 tree of size N is also an O(logN) operation. The depth of the tree ranges
from log N / log 2 (log base 2 of N), to log N / log 3 (log base 3 of N).
"""


class TwoThreeTree(AbstractSearchInterface):
    """A 2-3 balanced search tree with search, insert and delete operations."""

    def __init__(self, root=None):
        self.root = root

    def __get_child_index(self, element: str, node: TwoThreeNode) -> int:
        """Returns the index of the child (in node.children) to descend the
        tree to based on a given element.

        The index of the first key greater than the element is the index of the
        correct child. (If no key is greater, then descend to the rightmost
        child)
        """
        child_index = len(node.keys)
        for i, key in enumerate(node.keys):
            if element < key:
                child_index = i
                break
        return child_index

    def __search(self, element: str, node: TwoThreeNode) -> bool:
        """Recursively searches the tree rooted at node for element. Returns
        true if found.
        """
        if node is None:
            return False
        if element in node.keys:
            return True
        # Leaf reached without finding the element — the element is not in the
        # tree
        if node.is_leaf():
            return False
        # Get the index of the child to descend to
        child_index = self.__get_child_index(element, node)
        return self.__search(element, node.children[child_index])

    def searchElement(self, element: str) -> bool:
        """Returns true if and only if the 2-3 tree contains a specified
        element. Delegates work to a recursive helper, search.
        """
        if self.root is None:
            return False
        return self.__search(element, self.root)

    def __insert(
        self, element: str, node: TwoThreeNode
    ) -> None | tuple[str, TwoThreeNode, TwoThreeNode]:
        """Insert an element into a 2-3 subtree rooted at a given node, keeping
        the balance in check. This is a recursive helper method for insert.

        Returns:
          None : if the insertion is absorbed by the node without causing a
                 split operation
          middle_key, left_child, right_child (_, Node, Node) : if the node
                 split, the calling method must absorb the key being passed
                 up, and the left and right children
        """
        # Base case — leaf node
        if node.is_leaf():
            if element in node.keys:
                return None  # Duplicate
            # Insert the element
            node.keys.append(element)
            node.keys.sort()
            self.__inserted = True

            # Still a valid 2- or 3-node
            if len(node.keys) <= 2:
                return None

            # Overfull (has 3 keys) — split and pass the middle key up the
            # call chain
            middle_key = node.keys[1]
            left_child = TwoThreeNode([node.keys[0]])
            right_child = TwoThreeNode([node.keys[2]])
            return (middle_key, left_child, right_child)

        if element in node.keys:
            return None  # Duplicate

        # Recursive case — 2- or 3- (non-leaf) node
        # Find the correct child to recurse to
        child_index = self.__get_child_index(element, node)
        result = self.__insert(element, node.children[child_index])

        # Child absorbed the insert without splitting — so do nothing
        if result is None:
            return None

        # A child split, so absorb the received key and new children
        middle_key, left_child, right_child = result
        node.keys.append(middle_key)
        node.keys.sort()

        # Replace the child at child_index with the two new children
        node.children = (
            node.children[:child_index]
            + [left_child, right_child]
            + node.children[child_index + 1:]
        )

        # Still a valid 2- or 3-node — so do not initiate a split
        if len(node.keys) <= 2:
            return None

        # Overfull (has 3 keys) — split and pass (as before) but attach
        # children. Left child node gets the first two children, right child
        # node gets the last two
        middle_key = node.keys[1]
        left_child = TwoThreeNode([node.keys[0]], node.children[:2])
        right_child = TwoThreeNode([node.keys[2]], node.children[2:])
        return (middle_key, left_child, right_child)

    def insertElement(self, element: str) -> bool:
        """Insert an element into a 2-3 tree, keeping the balance in check.
        Delegates work to the recursive __insert method.
        """
        self.__inserted = False
        # If the tree is empty, then create a single leaf root
        if self.root is None:
            self.root = TwoThreeNode([element])
            return True

        result = self.__insert(element, self.root)

        # If the root split, then create a new one, one level higher
        # This is the only way the tree can grow taller
        if result is not None:
            middle_key, left_child, right_child = result
            self.root = TwoThreeNode([middle_key], [left_child, right_child])

        return self.__inserted

# %% [markdown]
# ### AVL Tree
# Use the cell below to implement the requested API by means of **AVL Tree** (if among your chosen data structure).

# %%
"""
An AVL tree (Adelson-Velsky and Landis) tree is another kind of balanced search tree with one extra invariant:
- For any node, |h(node.left) - h(node.right)| <= 1, where h : Node -> int, and h(Node) is the height of the subtree rooted at node.

This invariant — while relatively expensive to maintain — ensures an almost-perfect balance of the tree.
Combinations of left and right rotations are used to fix the tree to adhere to the rule.
"""


class AVLTree(AbstractSearchInterface):
    """An AVL tree with insert, search and delete operations."""

    def __init__(self, root=None):
        self.root = root

    def __height_of(self, node: AVLNode | None) -> int:
        """Returns the number of edges from a given node to its furthest leaf."""
        # -1 since height(leaf) = 1 + max(-1, -1) = 0
        if node is None:
            return -1
        else:
            return 1 + max(
                node.left.height if node.left is not None else -1,
                node.right.height if node.right is not None else -1,
            )

    def __get_balance(self, node: AVLNode) -> int:
        """Return the balance of a given node. Equal to left_height - right_height."""
        # Balance of root = left height - right height
        return self.__height_of(node.left) - self.__height_of(node.right)

    def __rotate_left(self, node: AVLNode) -> AVLNode:
        """Performs a left rotation about a given node.
        Returns the new root of node's subtree.
        """
        # Rotate
        right = node.right
        rightLeft = node.right.left
        node.right = rightLeft
        right.left = node

        # Update heights
        node.height = self.__height_of(node)
        right.height = self.__height_of(right)

        return right  # This is the new root

    def __rotate_right(self, node: AVLNode) -> AVLNode:
        """Performs a right rotation about a given node.
        Returns the new root of node's subtree.
        """
        # Rotate
        left = node.left
        leftRight = node.left.right
        node.left = leftRight
        left.right = node

        # Update heights
        node.height = self.__height_of(node)
        left.height = self.__height_of(left)

        return left  # This is the new root

    def __balance_node(self, node: AVLNode) -> tuple[AVLNode, bool]:
        """Fixes a node that breaks the invariant using rotation operations.
        Pushes the imbalance up the tree (until it reaches the root).
        Code assumes node.left and node.right are balanced.
        The boolean represents whether the height of the current node in the insertion path
        may have changed - if not, can stop calculating height / checking balance
        """
        # The height of child nodes may have changed, so the height of node may have changed also
        old_height = node.height
        node.height = self.__height_of(node)

        if node.height == old_height:
            return (node, False)

        balance = self.__get_balance(node)

        # If balanced, short circuit checking other conditions
        if -1 <= balance <= 1:
            return (node, True)
        elif balance > 1:
            # Case 1: left subtree too heavy and imbalance from left's left subtree
            if self.__get_balance(node.left) >= 0:
                return (self.__rotate_right(node), False)
            # Case 2: left subtree too heavy and imbalance from left's right subtree
            node.left = self.__rotate_left(node.left)
            return (self.__rotate_right(node), False)
        else:
            # Case 3: mirror of case 1
            if self.__get_balance(node.right) <= 0:
                return (self.__rotate_left(node), False)
            # Case 4: mirror of case 2
            node.right = self.__rotate_right(node.right)
            return (self.__rotate_left(node), False)

    def __search(self, element: str, node: AVLNode | None) -> bool:
        """Recursively searches the subtree rooted at node for element.
        Returns True if found.
        """
        if node is None:
            return False
        elif node.key == element:
            return True
        elif node.key > element:
            return self.__search(element, node.left)
        else:
            return self.__search(element, node.right)

    def searchElement(self, element: str) -> bool:
        found = self.__search(element, self.root)
        return found

    def __insert(self, element: str, node: AVLNode | None) -> tuple[AVLNode, bool]:
        """Recursively inserts an element into an AVL subtree rooted at node.
        Duplicates are assumed to have been filtered by the caller.
        The boolean represents whether the height of the current node in the insertion path
        may have changed - if not, can stop calculating height / checking balance
        """
        if node is None:
            self.__inserted = True
            return (AVLNode(element), True)
        elif node.key > element:
            node.left, check_height = self.__insert(element, node.left)
        elif node.key < element:
            node.right, check_height = self.__insert(element, node.right)
        else: # duplicate key
            return (node, False)

        if check_height:
            return self.__balance_node(node)
        return (node, False)

    def insertElement(self, element: str) -> bool:
        """Inserts an element into the AVL tree.
        Returns False if the element was already present; True otherwise.
        """
        self.__inserted = False
        self.root, _ = self.__insert(element, self.root)
        return self.__inserted

# %% [markdown]
# ### LLRB BST
# Use the cell below to implement the requested API by means of **LLRB BST** (if among your chosen data structure).

# %%
"""
LLRB Tree Implementation:

A LLRB tree (Left-Leaning Red-Black tree) is a balanced search tree that maintains the following extra invariants:
- Each node has an assigned colour (red or black), and has at most two children.
- The root of the tree is coloured black.
- A red node cannot have a red child.
- The black-height of all leaf nodes is constant (black-height is the number of black nodes between the leaf and the root).
- The right child of any node is coloured black (this is the left-leaning invariant).

The invariants are maintained through combinations of flip and rotate methods.
LLRB trees are isomorphic to 2-3 trees. Nodes with a red left child can be thought of as 3-nodes,
and nodes without a red link are 2-nodes. It is useful to think of this connection when reading the
deletion logic.

Searches and insertions are O(log n) operations. The tree's depth is bounded between
log_2(n + 1) and 2 * log_2(n + 1) inclusive, where n is the number of nodes in the tree.
"""


class LLRBTree(AbstractSearchInterface):
    """A Left-Leaning Red-Black tree with search, insert and delete operations."""

    def __init__(self, root=None):
        self.root = root

    def __is_red(self, node: LLRBNode | None) -> bool:
        """Returns True if the specified node exists and is red."""
        return node is not None and node.colour

    def __rotate_left(self, node: LLRBNode) -> LLRBNode:
        """Performs a left rotation about a given node."""
        right_child = node.right
        node.right = right_child.left
        right_child.left = node
        right_child.colour = node.colour
        node.colour = True
        return right_child

    def __rotate_right(self, node: LLRBNode) -> LLRBNode:
        """Performs a right rotation about a given node."""
        left_child = node.left
        node.left = left_child.right
        left_child.right = node
        left_child.colour = node.colour
        node.colour = True
        return left_child

    def __flip_colours(self, node: LLRBNode) -> LLRBNode:
        """Flips the colours of a given node and its two children."""
        node.colour = not node.colour
        node.left.colour = not node.left.colour
        node.right.colour = not node.right.colour
        return node

    def __fix_upward(self, node: LLRBNode) -> LLRBNode:
        """Fixes a node that breaks an invariant using rotation and flip operations.
        The rotations fix the error locally; the flip pushes the error up the tree.
        """
        # Case 1: Right child is red and left child is black — rotate left.
        if self.__is_red(node.right) and not self.__is_red(node.left):
            node = self.__rotate_left(node)
        # Case 2: Left child and its left child are both red — rotate right.
        if self.__is_red(node.left) and self.__is_red(node.left.left):
            node = self.__rotate_right(node)
        # Case 3: Both children are red — flip colours.
        if self.__is_red(node.left) and self.__is_red(node.right):
            node = self.__flip_colours(node)
        return node

    def __search(self, element: str, node: LLRBNode | None) -> bool:
        """Recursively searches the subtree rooted at node for element.
        Returns True if found.
        """
        if node is None:
            return False
        elif node.key == element:
            return True
        elif element < node.key:
            return self.__search(element, node.left)
        else:
            return self.__search(element, node.right)

    def searchElement(self, element: str) -> bool:
        """Searches the tree for element. Returns True if found; False otherwise."""
        return self.__search(element, self.root)

    def __insert(self, element: str, node: LLRBNode | None) -> LLRBNode:
        """Recursively inserts an element into the LLRB subtree rooted at node.
        Duplicates are assumed to have been filtered by the caller.
        """
        if node is None:
            self.__inserted = True
            return LLRBNode(element)

        if element < node.key:
            node.left = self.__insert(element, node.left)
        elif element > node.key:
            node.right = self.__insert(element, node.right)

        return self.__fix_upward(node)

    def insertElement(self, element: str) -> bool:
        """Inserts an element into the tree.
        Returns False if the element was already present; True otherwise.
        """
        self.__inserted = False
        self.root = self.__insert(element, self.root)
        self.root.colour = False
        return self.__inserted

# %% [markdown]
# ### Test Data Generator
# Use the cell below to implement the **synthetic data generator** needed by your experimental framework (be mindful of code readability and reusability).

# %%
import random


class TestDataGenerator:
    """
    A class to represent a synthetic data generator.

    Attributes
    ----------

    str_len: length of all keys generated
    lb: key lower bound
    ub: key upper bound
    normal_mean: parameter of the normal distribution
    normal_sd: parameter of the normal distribution

    Methods
    -------

    format: fixes the format of all keys to be consistent
    normal_data: returns a generator for randomly drawn values from a normal distribution
    uniform_data: returns a generator for randomly drawn values from a uniform distribution
    sorted_data: returns a generator for sorted values
    reverse_sorted_data: returns a generator for reverse sorted values
    """

    def __init__(self, str_len: int):
        self.__str_len = str_len
        self.__lb: int = 0
        self.__ub: int = 10**str_len
        self.__normal_mean: float = (self.__lb + self.__ub) / 2
        self.__normal_sd: float = (self.__ub - self.__normal_mean) / 3

    """
    Cast the value to int (truncate if it is a float)
    Cast the value to a string, and left-pad 0's to make all keys equal size in memory
    Left-pad preserves numerical order as lexicographic comparison is used on strings
    """

    def __format(self, value: int | float):
        return str(int(value)).zfill(self.__str_len)

    """ 
    Draws a random value from (a slightly truncated) normal distribution
    99.7% of values are within the lower and upper bound on keys
    Keys outside are discarded and rerolled
    """

    def normal_data(self):
        while True:
            value = random.gauss(self.__normal_mean, self.__normal_sd)
            if self.__lb <= value <= self.__ub:
                yield self.__format(value)

    def uniform_data(self):
        while True:
            value = random.randint(self.__lb, self.__ub)
            yield self.__format(value)

    def sorted_data(self):
        c = 0
        while True:
            yield self.__format(c)
            c = (c + 1) % self.__ub  # should never reach upper bound on keys

    def reverse_sorted_data(self):
        c = self.__ub
        while True:
            yield self.__format(c)
            c = (c - 1) if c > 0 else self.__ub

# %% [markdown]
# ### Experimental Framework
# Use the cell below to implement the requested **experimental framework** (be mindful of code readability and reusability).

# %%
import timeit
import random


class ExperimentalFramework:
    """
    A class to represent an experimental framework.

    Attributes
    ----------

    n: maximum size of a tree
    m: number of trees to build (number of searches + insertions at each size; size % i == 0 & size < n)
    r: the geometric spacing between timing a search and insertion ie (take measurements for every power of r)
    data_generator: an instance of TestDataGenerator for producing synthetic data
    implementations: a list of balanced tree implementations
    data_generator_methods: a list of synthetic data generation methods (all return a generator)

    Methods
    -------

    time_method_call: times the execution of a method (search or insert)
    get_random_key_in_structure: returns a key in the structure for searching
    get_random_key_not_in_structure: returns a key not in the structure for searching and inserting
    get_keys: returns a key guaranteed to be in the stucture, and one that is guaranteed not to be
    time_operations: times an insertion, and searches for a key in, and not in, the structure
    record_times: adds the times to the dictionary
    build_and_time_trees: builds balanced trees, timing operations as the tree grows
    test_implementations [PUBLIC]: builds the test data for each implementation and data generation method
    """

    def __init__(self, n: int, m: int, r: int):
        self.__n = n
        self.__m = m
        self.__r = r
        self.__data_generator = TestDataGenerator(7)
        self.__implementations = (TwoThreeTree, LLRBTree, AVLTree)
        self.__data_generator_methods = (
            self.__data_generator.uniform_data,
            self.__data_generator.normal_data,
            self.__data_generator.sorted_data,
            self.__data_generator.reverse_sorted_data,
        )

    def __time_method_call(self, method, *args):
        return timeit.timeit(lambda: method(*args), number=1)

    def __get_random_key_in_structure(self, keys_in_structure: list):
        return random.choice(keys_in_structure) if len(keys_in_structure) > 0 else None

    def __get_random_key_not_in_structure(
        self, structure: AbstractSearchInterface, data_generator
    ):
        key = next(data_generator)
        while structure.searchElement(key):
            key = next(data_generator)
        return key

    def __get_keys(
        self,
        structure: AbstractSearchInterface,
        data_generator,
        keys_in_structure: list,
    ):
        in_structure = self.__get_random_key_in_structure(keys_in_structure)
        not_in_structure = self.__get_random_key_not_in_structure(
            structure, data_generator
        )
        return in_structure, not_in_structure

    def __time_operations(self, structure: AbstractSearchInterface, in_key, not_in_key):
        insert_method, search_method = getattr(structure, "insertElement"), getattr(
            structure, "searchElement"
        )
        if random.randint(0,1) == 0: # Randomise search order to remove cache-warming bias
            search_in = self.__time_method_call(search_method, in_key)
            search_not_in = self.__time_method_call(search_method, not_in_key)
        else:
            search_not_in = self.__time_method_call(search_method, not_in_key)
            search_in = self.__time_method_call(search_method, in_key)
            
        insert = self.__time_method_call(insert_method, not_in_key)
        return insert, search_in, search_not_in

    def __record_times(
        self,
        times_dict: dict[str, dict[int, list[float]]],
        size,
        insert,
        search_in,
        search_not_in,
    ):
        if size in times_dict["insert"]:
            times_dict["insert"][size].append(insert)
            times_dict["search_in"][size].append(search_in)
            times_dict["search_not_in"][size].append(search_not_in)
        else:
            times_dict["insert"][size] = [insert]
            times_dict["search_in"][size] = [search_in]
            times_dict["search_not_in"][size] = [search_not_in]

    def __build_and_time_trees(
        self, implementation: type[AbstractSearchInterface], data_generator_method
    ):
        times = {"insert": dict(), "search_in": dict(),
                 "search_not_in": dict()}
        for _ in range(self.__m):
            structure = implementation()
            data_generator = data_generator_method()
            keys_in_structure = list()
            next_size, ratio = 1, self.__r
            for size in range(self.__n):
                in_key, not_in_key = self.__get_keys(
                    structure, data_generator, keys_in_structure
                )
                keys_in_structure.append(not_in_key)
                if size == next_size and size > 0:
                    next_size = max(next_size + 1, int(next_size * ratio))
                    insert, search_in, search_not_in = self.__time_operations(
                        structure, in_key, not_in_key
                    )
                    self.__record_times(times, size, insert,
                                        search_in, search_not_in)
                else:
                    structure.insertElement(not_in_key)
        return times

    def test_implementations(self):
        results = dict()
        for implementation in self.__implementations:
            print(f"Timing implementation: {implementation}")
            distribution_results = dict()
            for distribution in self.__data_generator_methods:
                print(f"Timing distribution: {distribution}")
                times = self.__build_and_time_trees(
                    implementation, distribution
                )
                distribution_results[distribution.__name__] = times
            results[implementation.__name__] = distribution_results
        return results

# %% [markdown]
# ### Maths, Statistics Framework, & Graphing
# Use the cell below to illustrate the python code you used to **fully evaluate** your three chosen search data structures and algortihms. The code below should illustrate, for example, how you made used of the **TestDataGenerator** class to generate test data of various size and properties; how you instatiated the **ExperimentalFramework** class to  evaluate each data structure using such data, collect information about their execution time, plot results, etc. Any results you illustrate in the companion PDF report should have been generated using the code below.

# %%
class MathsHelper:
    '''Contains methods to calculate logs and exponents.
    '''
    E = 2.718281828459045235360287471352
    log_table = None

    @staticmethod
    def exp(base=E, i=1):
        return base**i

    @staticmethod
    def __log_approximation_binary_search(low, high, n, epsilon):
        ''' 
        Can encounter floating point precision issues
        '''
        diff = MathsHelper.exp(MathsHelper.E, i=low)
        while diff < -epsilon or diff > epsilon:
            mid = (low + high) / 2
            approximation = MathsHelper.exp(MathsHelper.E, i=mid)
            diff = n - approximation
            if approximation < n:
                low = mid
            if approximation > n:
                high = mid
        return mid

    @staticmethod
    def __slow_log(n=1):
        high = 0
        while MathsHelper.exp(base=MathsHelper.E, i=high) < n:
            high += 1
        return MathsHelper.__log_approximation_binary_search(high - 1, high, n, 0.000001)
    
    @classmethod
    def _build_log_table(cls, max_n = 10**6):
        if cls.log_table is None:
            cls.log_table = [0.0] * (max_n + 1)
            for i in range(1, max_n + 1):
                cls.log_table[i] = cls.__slow_log(i)

    @staticmethod
    def log(n):
        if MathsHelper.log_table is None:
            MathsHelper._build_log_table()
    
        if 1 <= n < len(MathsHelper.log_table) and n == int(n):
            return MathsHelper.log_table[int(n)]
        return MathsHelper.__slow_log(n)

# %%
class StatisticsFramework:
    ''' Calculates some statistics / fits a regression line to the data.

    - mean, variance, standard_deviation and standard_error methods operate on a list of input numerical data.
    - The display_basic_statistics method shows you how to use them properly (and the correct units)

    - logarithmic fit returns the coefficients that best fit y = a + b log(x)
    - get_logarithmic_PMCC returns the PMCC for this model
    - get_logarithmic_r2 returns the coefficient of determination (the PMCC squared)

    - get_logarithmic_residuals returns a list of residuals (actual - predicted) for the model.
    It takes in x_data, y_data, a, b where a and b are the coefficients.
    It would be useful to plot this against log(x) using a scatter graph - since it visualises the goodness-of-fit of our model.
    We would expect randomly distributed data points about 0. 

    - If we can't do this plot, then get_RMSE takes in the list of residuals and calculates their variation about 0. 
    This is another decent (but not as good) way of showing the goodness-of-fit.
    - See display_logarithmic_fit_statistics for an example of use.

    The whole motivation to evaluate the goodness-of-fit of a logarithmic model is that it will show our trees are operating in-line with theory.
    (We expect insert and search to be O(logN) time algorithms) for all trees.

    - (IMPORTANT) Ideally, the standard errors for each sample should be plotted as vertical error bars on our graphs.
    They show the region in which the sample means are likely to fall into. These work (approximately) like standard deviations -
    we expect ~68% of sample means to fall within 1 std-err of our data point. ~95% within 2 std-errors, and 99.7% within 3. 
    The error bars will give an evaluation of how confident we are in our measurements. 

    '''

    def mean(self, data):
        return sum(data) / len(data)

    def variance(self, data):
        ''' Calculates the variance in a list of numerical data.
        '''
        n = len(data)
        mean = self.mean(data)
        Sxx = self.__sum_squared_deviation(data, mean)
        return Sxx / (n-1)  # this is the sample variance

    def median(self, data):
        '''Calculates the median on a list of numerical data
        '''
        return sorted(data)[len(data)//2]

    def remove_outliers(self, data):
        '''Removes extreme outliers from a list of numerical data using IQR method with k = 1.5.
        '''
        n = len(data)
        sorted_data = sorted(data)

        lower_quartile = sorted_data[n // 4]
        upper_quartile = sorted_data[3 * n // 4]
        inter_quartile_range = upper_quartile - lower_quartile
        lower_bound = lower_quartile - 1.5 * inter_quartile_range
        upper_bound = upper_quartile + 1.5 * inter_quartile_range

        return [x for x in sorted_data if lower_bound <= x <= upper_bound]
    
    def outlier_frequency(self, data):
        '''Returns the frequency of outliers in a list of numerical data.
        '''
        n = len(data)
        cleaned_data = self.remove_outliers(data)
        self.outlier_frequency = 100.0 * (1 - (len(cleaned_data) / n))

    def standard_deviation(self, data):
        '''Calculates the standard deviation in a list of numerical data.
        '''
        return self.variance(data)**0.5

    def standard_error(self, data):
        '''Returns the standard error of the mean for a list of numerical data.
        Equal to, the sample standard deviation / sqrt(n), where n is the number of elements in the list.
        The standard error estimates the standard deviation of the of distribution of sample means. That is, an estimate of how the sample mean varies over repeated samples. 
        '''
        n = len(data)
        return self.standard_deviation(data) / n*0.5

    def logarithmic_fit(self, x_data, y_data):
        '''Return the coefficients for the logarithmic regression of y_data on x_data.
        That is, the values (a,b) such that y = a + b * ln(x) best fits the data.
        '''

        log_x_data = self.natural_log_data(x_data)
        (a, b) = self.__linear_fit(log_x_data, y_data)

        return (a, b)

    def get_logarithmic_PMCC(self, x_data, y_data):
        '''Returns the PMCC of the regression line of y_data on log(x_data).
        '''
        log_x_data = self.natural_log_data(x_data)
        return self.__get_linear_PMCC(log_x_data, y_data)

    def get_logarithmic_r2(self, x_data, y_data):
        ''' Returns r-squared (the PMCC squared). 
        This is a value in the interval [0,1] that tells us the proportion of the variance in the data that the fitted model accurately captures.
        '''
        return self.get_logarithmic_PMCC(x_data, y_data) ** 2

    def get_logarithmic_residuals(self, x_data, y_data, a, b):
        '''Return the residuals (actual - predicted) values for the logarithmic fit as a list
        Parameters 'a' and 'b' are the values a, b in the model y = a + b * log(x)
        '''
        n = len(x_data)

        def f(x): return a + b * MathsHelper.log(x)

        return [y_data[i] - f(x_data[i]) for i in range(n)]

    def get_RMSE(self, residuals):
        '''Returns the RMSE of the model for the fitted data. This is the Root of the Mean of the Squared Errors.
        It is a measure of the spread (standard deviation) of the errors about 0 
        Given by: (the sum of the squares of the residuals / n)^1/2
        '''
        n = len(residuals)
        return (sum([r**2 for r in residuals]) / n)**0.5

    def basic_statistics(self, data):
        '''Calculates the following statistics about a list of numeric data:
        sample mean, sample variance, sample standard deviation and sample standard error
        '''
        return {
            "mean": self.mean(data),
            "variance": self.variance(data),
            "standard_deviation": self.standard_deviation(data),
            "standard_error": self.standard_error(data),
            "outlier_percentage": self.outlier_percentage(data)
        }

    def format_basic_statistics(self, statistics):
        '''Formats and returns a string of the basic statistics.
        '''
        return (
            f"The basic statistics are:\n"
            f"The sample mean is: {statistics['mean']} seconds\n"
            f"The sample variance is: {statistics['variance']} seconds^2\n"
            f"The sample standard deviation is: {statistics['standard_deviation']} seconds\n"
            f"The sample standard error is: {statistics['standard_error']} seconds\n"
            f"The sample outlier rate is: {statistics['outlier_frequency'] * 100.0}%"
        )

    def logarithmic_fit_statistics(self, x_data, y_data):
        '''Fits a logarithmic model, y = a + b * log(x), to y_data and x_data. 
        And returns the following statistics: 
        coefficents of the line of best fit, the PMCC for that line, r^2 (also known as the coefficient of determination, and the RMSE)
        Note, the class also has a method to provide the residuals as list; but this data needs to be plotted.
        '''

        a, b = self.logarithmic_fit(x_data, y_data)
        pmcc = self.get_logarithmic_PMCC(x_data, y_data)
        r2 = self.get_logarithmic_r2(x_data, y_data)
        residuals = self.get_logarithmic_residuals(x_data, y_data, a, b)
        rmse = self.get_RMSE(residuals)

        return {
            "a": a,
            "b": b,
            "pmcc": pmcc,
            "r2": r2,
            "residuals": residuals,
            "rmse": rmse
        }

    def format_logarithmic_fit_statistics(self, statistics):
        return (
            f"The regression statistics are:\n"
            f"The model of best fit is: y = {statistics['a']} + {statistics['b']}*log(x)\n"
            f"The PMCC is: {statistics['pmcc']}\n"
            f"The coefficient of determination (r^2) is: {statistics['r2']}\n"
            f"The RMSE is: {statistics['rmse']} seconds\n"
        )

    def natural_log_data(self, data):
        '''Return a list of the natural logarithms of each value.
        '''
        if any([x <= 0 for x in data]):
            raise ValueError(
                "You cannot log a non-positive number - check logic.")
        return [MathsHelper.log(i) for i in data]

    def __linear_fit(self, x_data, y_data):
        '''Return the coefficients for the linear regression of y_data on x_data.
        Being, (a, b) where y = a + b * x best fits the data.
        Using the formulae: b = Sxy / Sxx - the ratio of covariance and variance
        And, a = y_mean - b * x_mean - the y-intercept of a line with gradient b passing through (x_mean, y_mean)
        '''
        x_mean, y_mean, Sxx, _, Sxy = self.__get_summary_statistics(
            x_data, y_data)

        b = Sxy / Sxx  # Equivalent to the covariance / variance
        # Line of best fit passes through (x_mean, y_mean)
        a = y_mean - b * x_mean

        return (a, b)

    def __get_linear_PMCC(self, x_data, y_data):
        '''Return the product moment correlation coefficient of the linear relationship between y_data and x_data
        Calculation is equivalent to co-variance of x_data and y_data / (standard deviation in x_data * standard deviation in y_data)
        '''

        _, _, Sxx, Syy, Sxy = self.__get_summary_statistics(x_data, y_data)
        return Sxy / (Sxx * Syy)**0.5

    def __get_summary_statistics(self, x_data, y_data):
        '''Returns some summative statistics about the data used frequently in regression calculations.
        '''

        x_mean = self.mean(x_data)
        y_mean = self.mean(y_data)

        Sxx = self.__sum_squared_deviation(x_data, x_mean)
        Syy = self.__sum_squared_deviation(y_data, y_mean)
        Sxy = self.__sum_co_deviations(x_data, y_data, x_mean, y_mean)

        return (x_mean, y_mean, Sxx, Syy, Sxy)

    def __sum_co_deviations(self, x_data, y_data, x_mean, y_mean):
        '''Returns S_xy (a summary statistic for n * covariance) between two lists of numerical data.
        '''
        if len(x_data) != len(y_data):
            raise ValueError("x_data and y_data points are mismatched")
        n = len(x_data)

        return sum([(x_data[i] - x_mean) * (y_data[i] - y_mean) for i in range(n)])

    def __sum_squared_deviation(self, x_data, x_mean):
        ''' Returns S_xx (a summary statistic for n * variance) in a list of numerical data.
        '''
        n = len(x_data)

        return sum([(x_data[i] - x_mean)**2 for i in range(n)])

# %%
''' 
Parameters for the experimental framework
For 'large' N qualitative experiments, use N = 10**6, and M = 3 - these have been excluded to save on runtime.
'''
N = 10**4
M = 250
data_points = 250
R = MathsHelper.exp(MathsHelper.log(N) / data_points)

# %%
class graphData:
    '''Stores data for graphing.
    '''
    def __init__(self, title, x_data, y_data):
        self.title = title
        self.x_data = x_data  # save original x_data
        self.logged_x_data = x_data
        self.y_data = y_data

    def set_logged_x_data(self, logged_x_data):
        self.logged_x_data = logged_x_data

    def set_regression_coefficients(self, a, b):
        self.a, self.b = a, b

    def set_error_bars(self, errors):
        self.errors = errors

    def set_residuals(self, residuals):
        self.residuals = residuals

    def set_summary_text(self, summary_text):
        self.summary_text = summary_text


class Main:
    '''Runs the tests and prepares data for graphing.
    '''
    def __init__(self):
        self.sf = StatisticsFramework()

    def run_tests(self):
        experimentalFramework = ExperimentalFramework(n=N, m=M, r=R)
        test_data = experimentalFramework.test_implementations()
        return test_data

    def process_timing_data(self, timings):
        cleaned_data = self.sf.remove_outliers(timings)
        mean_time = self.sf.mean(cleaned_data)
        std_err = self.sf.standard_error(cleaned_data)
        outliers_removed = len(timings) - len(cleaned_data)
        return mean_time, std_err, outliers_removed

    def process_data_for_graphing(self, test_data):
        '''Returns a list of graphData object to be displayed via matplotlib
        '''
        graphs_to_draw = []
        for structure, structure_data in test_data.items():
            #   for experiment, experiment_data in structure_data.items():
            # for distribution, distribution_data in experiment_data.items():
            for distribution, distribution_data in structure_data.items():
                for experiment, experiment_data in distribution_data.items():
                    title = structure + " " + experiment + " " + distribution

                    total_points = total_outliers = 0.0

                    x_data = []
                    y_data = []
                    std_errors = []
                    
                    for size, timings in experiment_data.items():
                        x_val = size
                        y_val, std_err, outliers_removed = self.process_timing_data(timings)
                        total_points += len(timings)
                        total_outliers += outliers_removed
                        x_data.append(x_val)
                        y_data.append(y_val)
                        std_errors.append(std_err)

                    graph = graphData(title, x_data, y_data)
                    graph.set_error_bars(std_errors)

                    graph.set_logged_x_data(self.sf.natural_log_data(x_data))

                    a, b = self.sf.logarithmic_fit(x_data, y_data)
                    graph.set_regression_coefficients(a, b)

                    residuals = self.sf.get_logarithmic_residuals(
                        x_data, y_data, a, b)
                    graph.set_residuals(residuals)

                    outlier_percentage = 100.0 * total_outliers / total_points
                    graph.set_summary_text(self.sf.format_logarithmic_fit_statistics(
                        self.sf.logarithmic_fit_statistics(x_data, y_data))
                          + f"The outlier rate was: {outlier_percentage: .4}%")

                    graphs_to_draw.append(graph)

        return graphs_to_draw


main = Main()
test_data = main.run_tests()
graphs_to_draw = main.process_data_for_graphing(test_data)
# Out:
# Timing implementation: <class '__main__.TwoThreeTree'>
# Timing distribution: <bound method TestDataGenerator.uniform_data of <__main__.TestDataGenerator object at 0x16898e750>>
# Timing distribution: <bound method TestDataGenerator.normal_data of <__main__.TestDataGenerator object at 0x16898e750>>
# Timing distribution: <bound method TestDataGenerator.sorted_data of <__main__.TestDataGenerator object at 0x16898e750>>
# Timing distribution: <bound method TestDataGenerator.reverse_sorted_data of <__main__.TestDataGenerator object at 0x16898e750>>
# Timing implementation: <class '__main__.LLRBTree'>
# Timing distribution: <bound method TestDataGenerator.uniform_data of <__main__.TestDataGenerator object at 0x16898e750>>
# Timing distribution: <bound method TestDataGenerator.normal_data of <__main__.TestDataGenerator object at 0x16898e750>>
# Timing distribution: <bound method TestDataGenerator.sorted_data of <__main__.TestDataGenerator object at 0x16898e750>>
# ...

# %%
import matplotlib.pyplot as plt

'''Draws two sets of graphs: graphs for each type of tree, and comparative plots.
'''
grouped_graphs = {}
for graph in graphs_to_draw:
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(
        8, 6), gridspec_kw={"height_ratios": [3, 1]})

    x = graph.logged_x_data
    y = graph.y_data
    y_fit = [graph.a + graph.b * xi for xi in x]

    ax1.errorbar(x, y, yerr=graph.errors, fmt='o',
                 capsize=4, label='Mean time')
    ax1.plot(x, y_fit, '-', label='Log fit')
    ax1.set_title(graph.title)
    ax1.set_xlabel('ln(n)')
    ax1.set_ylabel('Time (s)')
    ax1.legend()
    ax1.grid(True, alpha=0.3)
    ax1.ticklabel_format(axis='y', style='sci', scilimits=(-6, -6))

    ax2.scatter(x, graph.residuals)
    ax2.axhline(0, color='red', linestyle='--')
    ax2.set_xlabel('ln(n)')
    ax2.set_ylabel('Residuals')
    ax2.grid(True, alpha=0.3)

    fig.text(0, 0, graph.summary_text, fontsize=10, va='bottom')
    plt.tight_layout(rect=(0, 0.15, 1, 1))
    plt.show()

for graph in graphs_to_draw:
    structure, experiment, distribution = graph.title.split(' ', 2)
    grouped_graphs.setdefault((experiment, distribution), []).append((structure, graph))

colours = ['tab:blue', 'tab:orange', 'tab:green']

for (experiment, distribution), group in grouped_graphs.items():
    fig, (ax1, ax2, ax3) = plt.subplots(
        3, 1, figsize=(12, 9), gridspec_kw={"height_ratios": [3, 1, 2]})
    summary_lines = []

    for colour, (structure, graph) in zip(colours, sorted(group, key=lambda item: item[0])):
        points = sorted(zip(graph.logged_x_data, graph.y_data,
                        graph.errors), key=lambda p: p[0])
        x, y, errors = zip(*points)
        ax1.errorbar(x, y, yerr=graph.errors, fmt='-o', color=colour,
                     capsize=4, alpha=0.8, label=f'{structure} mean')

        x = graph.logged_x_data
        y = graph.y_data
        y_fit = [graph.a + graph.b * xi for xi in x]

        ax1.plot(x, y_fit, '-', color=colour, linewidth=2,
                 label=f'{structure} log fit')
        ax2.scatter(x, graph.residuals, color=colour,
                    alpha=0.8, label=structure)

        summary_lines.append(f'{structure}: {graph.summary_text}')

    ax1.set_title(f'{experiment} {distribution}')
    ax1.set_xlabel('ln(n)')
    ax1.set_ylabel('Time (s)')
    ax1.legend(ncol=2)
    ax1.grid(True, alpha=0.3)
    ax1.ticklabel_format(axis='y', style='sci', scilimits=(-6, -6))

    ax2.axhline(0, color='red', linestyle='--')
    ax2.set_xlabel('ln(n)')
    ax2.set_ylabel('Residuals')
    ax2.legend()
    ax2.grid(True, alpha=0.3)

    ax3.axis('off')
    ax3.text(0.01, 0.98, '\n\n'.join(summary_lines), fontsize=12,
             va='top', ha='left', transform=ax3.transAxes)

    plt.tight_layout()
    plt.show()
